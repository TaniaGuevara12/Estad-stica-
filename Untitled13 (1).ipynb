# %% [markdown]
# PARTE (**A**)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# Obtener datos de acciones
df = yf.download(
    tickers='AMZN',            # tickers: AAPL: Apple, TSLA: Tesla, etc.
    start='2023-07-01',        # Fecha de inicio
    end='2025-04-01',          # Fecha de fin
    interval='1d',             # Intervalo de tiempo (1 día)
    group_by=None,             # Agrupar por ticker
    auto_adjust=False,         # ajusta automáticamente los precios de cierre, apertura, máximo y mínimo para tener en cuenta los dividendos y divisiones de acciones.
    actions=False,             # Si se establece en True, incluye datos sobre acciones, como dividendos y divisiones.
    )

# Link para inspeccionar tickers: https://www.nasdaq.com/market-activity/stocks/screener

# Paso 1: Mover 'Date' del índice a columna regular
df = df.reset_index()

# Paso 2: Aplanar el MultiIndex de las columnas, manteniendo 'Open', 'High', etc.
df.columns = ['_'.join(col).strip() if col[1] != '' else col[0] for col in df.columns.values]


# Paso 3:
#######################################################
## En caso de que no se requiera la hora
# Convertir la columna 'Date' a tipo datetime si no lo es ya
df['Date'] = pd.to_datetime(df['Date'])

df['Date'] = df['Date'].dt.date
##
#######################################################

# Paso 4: La fecha vuelve a ser un índice
df.set_index('Date', inplace=True)


df
# Out:
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['AMZN']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# Empty DataFrame
# Columns: [AMZN_Open, AMZN_High, AMZN_Low, AMZN_Close, AMZN_Adj Close, AMZN_Volume]
# Index: []

# %%
pip install alpha_vantage

# %%
# !pip install alpha_vantage
from alpha_vantage.timeseries import TimeSeries
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
import warnings
warnings.filterwarnings('ignore')

# Entra a https://www.alphavantage.co/support/#api-key
# Registrate para obtener tu api-key

# Tu clave de API (reemplaza esta por la tuya)
my_key = 'AKR7WBUW4WO3K3BV'   # esta es mía, no la uses o habrá problemas

# Crear objeto TimeSeries
ts = TimeSeries(key=my_key, output_format='pandas')

# Obtener datos diarios de AMZN
ticker = 'AMZN'
data, meta = ts.get_daily(symbol=ticker, outputsize='full')

columnas = [ticker + '_' + i for i in ['Open', 'High', 'Low', 'Close', 'Volume']]
data.columns = columnas

inicio = '2023-07-01'
fin = '2025-04-01'
df = data[(data.index >= inicio) & (data.index <= fin)]

df
# Out:
# ...
#             AMZN_Open  AMZN_High  AMZN_Low  AMZN_Close  AMZN_Volume
# date
# 2025-04-01    187.860     193.93  187.2000      192.17   41267315.0
# 2025-03-31    188.190     191.33  184.4000      190.26   63547558.0
# 2025-03-28    198.420     199.26  191.8810      192.72   52548226.0
# 2025-03-27    200.890     203.79  199.2821      201.36   27317661.0
# 2025-03-26    205.835     206.01  199.9250      201.13   32990973.0
# ...               ...        ...       ...         ...          ...
# 2023-07-10    129.070     129.28  125.9150      127.13   61889289.0
# 2023-07-07    128.590     130.97  128.1294      129.78   41992251.0
# 2023-07-06    128.250     128.73  127.3700      128.36   40697848.0
# 2023-07-05    130.240     131.40  129.6400      130.38   35895409.0
# 2023-07-03    130.820     131.85  130.0650      130.22   28264785.0
#
# [439 rows x 5 columns]

# %%
# Promedio Móvil Simple
ventana_sma = 20
df['SMA'] = df['AMZN_Close'].rolling(window=ventana_sma).mean()

# Promedio Móvil Exponencial
ventana_ses = 100
df['SES'] = df['AMZN_Close'].ewm(span=ventana_ses, adjust=False).mean()

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(df['AMZN_Close'], label='Precio de Cierre', color='turquoise')
plt.plot(df['SMA'], label=f'Promedio Móvil ({ventana_sma} días)', color='pink')
plt.plot(df['SES'], label=f'Suavización Exponencial ({ventana_ses} días)', color='purple')
plt.title('Promedio Móvil de Precios de Cierre de AMZN_Close')
plt.xlabel('Fecha')
plt.ylabel('Precio de Cierre ($)')
plt.grid()
plt.legend()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# conclusión
#
# Se observa que el precio de cierre (línea turquesa) presenta una alta volatilidad diaria, reflejando las fluctuaciones del mercado. El promedio móvil simple (línea rosa) sigue de cerca al precio real, pero con un pequeño rezago, lo cual lo hace útil para identificar tendencias a corto plazo y posibles puntos de inflexión. Por otro lado, la suavización exponencial (línea morada), al tener una ventana más amplia y mayor peso en datos recientes, proporciona una visión más estable y de tendencia general a largo plazo. Esta última reacciona más lentamente a cambios abruptos, pero es más útil para evaluar la dirección predominante del mercado.

# %% [markdown]
# PARTE (**B**)
# ### Prueba Dickey-Fuller Aumentada

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['AMZN_Close'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -0.6493891124859386
# p-value: 0.8594271507428344
# La tendencia no es estacionaria (aceptamos la hipótesis nula).

# %% [markdown]
# **La prueba ADF arrojó un estadístico de -0.6493 y un valor p superior al nivel de significancia (0.05). Dado que no se rechaza la hipótesis nula, se concluye que la serie temporal no es estacionaria. Esto implica que la media y la varianza de la serie cambian en el tiempo.**

# %% [markdown]
# PARTE (C)
#
# REGRESION POLINOMIAL

# %%
from numpy.polynomial.polynomial import Polynomial

# Paso 1: Convertir fechas a números
# Creamos una nueva columna llamada 'Date' la cual contiene las fechas en
# segundos desde el 1 de de enero de 1970 (tiempo UNIX)
df['Date'] = pd.to_datetime(df.index).map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['AMZN_Close']

# Paso 3: Ajustar un modelo polinómico
grado = 7
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Precio de Cierre', # etiqueta que aparecerá en la leyenda
    color='pink'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Precios de Cierre de AMZN_Close') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('Precio de Cierre ($)')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()                                                    # muestra el gráfico (innecesario en colab)




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='turquoise')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresion polinomial de Cierre de AMZN_Close')
plt.xlabel('Fecha')
plt.ylabel('Desviacion de la regresion polinomial ($)')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# conclusión
#
# La tendencia polinómica de grado 7 capta la forma general del comportamiento del precio: Este modelo muestra una curva suavizada que aproxima la evolución general del precio a lo largo del periodo. Sin embargo, tiende a sobreajustar en los extremos, lo cual puede generar errores si se usa para predicción futura.
#
# Los residuales del modelo polinómico se distribuyen con cierta simetría: La gráfica de los residuales muestra que las desviaciones del modelo no siguen un patrón sistemático, aunque en algunos puntos hay desviaciones marcadas. Esto sugiere que el modelo captura una parte importante de la tendencia, pero no explica completamente la variabilidad del precio

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['Poly_Resid'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:(residuales)', adf_test[0])
print('p-value:(residuales)', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF:(residuales) -6.147278832855708
# p-value:(residuales) 7.712635018692181e-08
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# Conclusión
#
# Con base en los resultados obtenidos mediante la prueba de Dickey-Fuller aumentada (ADF) aplicada a los residuales del modelo polinómico ajustado al precio de cierre de la acción de Amazon (AMZN), se concluye que la serie de los residuales es estacionaria. Esto se evidencia por el valor del estadístico ADF de aproximadamente -6.15 y un valor p (p-value) muy cercano a cero (7.71e-08), lo cual es significativamente menor al nivel de significancia utilizado (α = 0.05). Dado que el valor p es menor al umbral, se rechaza la hipótesis nula de que la serie tiene una raíz unitaria y, por lo tanto, no es estacionaria.

# %% [markdown]
# # **CONCLUSIONES GENERALES **
#
#
# El precio de cierre de AMZN presenta
# variaciones suaves pero con tendencias marcadas:
# La gráfica muestra que los precios de AMZN no son completamente erráticos, sino que tienen tendencias identificables, especialmente a lo largo de varios meses.
#
# La media móvil simple suaviza las fluctuaciones a corto plazo:
# La línea SMA de 20 días ayuda a identificar la dirección general del mercado, aunque responde lentamente a cambios bruscos. Es útil para observar tendencias a corto plazo, pero puede no reaccionar oportunamente a cambios rápidos.
#
# La suavización exponencial ofrece una respuesta más dinámica:
# El SES de 100 días, al pesar más los datos recientes, sigue mejor las subidas y bajadas recientes del precio, lo cual puede ser más útil para decisiones de inversión con enfoque en cambios recientes del mercado.
#
# La tendencia polinómica de grado 7 capta la forma general del comportamiento del precio:
# Este modelo muestra una curva suavizada que aproxima la evolución general del precio a lo largo del periodo. Sin embargo, tiende a sobreajustar en los extremos, lo cual puede generar errores si se usa para predicción futura.
#
# Los residuales del modelo polinómico se distribuyen con cierta simetría:
# La gráfica de los residuales muestra que las desviaciones del modelo no siguen un patrón sistemático, aunque en algunos puntos hay desviaciones marcadas. Esto sugiere que el modelo captura una parte importante de la tendencia, pero no explica completamente la variabilidad del precio
