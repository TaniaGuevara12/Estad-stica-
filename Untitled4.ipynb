# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/TaniaGuevara12/Estad-stica-/refs/heads/main/life_expectancy.csv')
df.head(60)
# Out:
#                      Country  Sum of Females  Life Expectancy  \
# 0                       Chad                            57.19
# 1                    Nigeria                            54.94
# 2                South Sudan                            60.75
# 3                    Lesotho                            60.44
# 4   Central African Republic                            59.56
# 5                    Somalia                            61.55
# 6               Burkina Faso                            63.43
# 7                       Mali                            62.15
# 8                      Benin                            62.42
# 9                     Guinea                            62.09
# 10                  DR Congo                            64.23
# 11             Côte d'Ivoire                            64.31
# 12              Sierra Leone                            63.70
# 13                Mozambique                            66.74
# 14                     Niger                            62.41
# 15                  Zimbabwe                            65.31
# 16                   Liberia                            63.63
# 17                  Eswatini                            67.11
# 18                     Kenya                            66.12
# 19                   Burundi                            65.88
# 20                  Cameroon                            66.23
# 21             Guinea-Bissau                            66.55
# 22                     Haiti                            68.49
# 23                Madagascar                            65.60
# 24         Equatorial Guinea                            65.89
# 25                    Angola                            67.34
# 26                      Togo                            63.15
# 27              South Africa                            69.79
# 28                     Ghana                            68.16
# 29                   Namibia                            71.48
# 30                     Sudan                            69.83
# 31                  Djibouti                            68.74
# 32          Papua New Guinea                            69.21
# 33                   Myanmar                            70.38
# 34                    Zambia                            68.87
# 35                    Malawi                            70.77
# 36                     Congo                            67.72
# 37                    Gambia                            67.75
# 38                  Ethiopia                            71.02
# 39                  Tanzania                            70.00
# 40                  Kiribati                            68.32
# 41               Afghanistan                            67.81
# 42                   Comoros                            69.20
# 43        State of Palestine                            74.25
# 44                  Pakistan                            70.32
# 45                      Fiji                            69.54
# 46                    Uganda                            71.37
# 47                    Rwanda                            70.14
# 48                     Gabon                            71.24
# 49                   Bolivia                            71.32
# 50               Timor-Leste                            69.67
# 51       Sao Tome & Principe                            73.91
# 52                    Guyana                            74.09
# 53                Mauritania                            70.73
# 54                   Moldova                            75.67
# 55                   Eritrea                            70.94
# 56                  Botswana                            71.85
# 57               Philippines                            72.96
# 58              Turkmenistan                            73.01
# 59                   Senegal                            71.01
#
#     Sum of Life Expectancy  (both sexes)  Sum of Males  Life Expectancy
# 0                                  55.24                          53.36
# 1                                  54.64                          54.33
# 2                                  57.74                          54.76
# 3                                  57.80                          55.03
# 4                                  57.67                          55.51
# 5                                  58.97                          56.49
# 6                                  61.29                          59.11
# 7                                  60.68                          59.25
# 8                                  60.96                          59.52
# 9                                  60.90                          59.66
# 10                                 62.07                          59.96
# 11                                 62.11                          60.17
# 12                                 61.96                          60.23
# 13                                 63.80                          60.49
# 14                                 61.43                          60.49
# 15                                 63.06                          60.49
# 16                                 62.32                          61.02
# 17                                 64.26                          61.32
# 18                                 63.83                          61.64
# 19                                 63.82                          61.75
# 20                                 63.97                          61.78
# 21                                 64.25                          61.82
# 22                                 65.12                          61.90
# 23                                 63.84                          62.12
# 24                                 63.91                          62.22
# 25                                 64.81                          62.28
# 26                                 62.93                          62.70
# 27                                 66.31                          62.78
# 28                                 65.70                          63.31
# 29                                 67.52                          63.45
# 30                                 66.52                          63.45
# 31                                 66.20                          63.73
# 32                                 66.26                          63.84
# 33                                 67.10                          63.99
# 34                                 66.53                          64.10
# 35                                 67.56                          64.27
# 36                                 66.00                          64.33
# 37                                 66.06                          64.35
# 38                                 67.60                          64.36
# 39                                 67.21                          64.40
# 40                                 66.60                          64.69
# 41                                 66.29                          64.70
# 42                                 67.02                          65.02
# 43                                 69.21                          65.22
# 44                                 67.80                          65.46
# 45                                 67.46                          65.47
# 46                                 68.49                          65.49
# 47                                 68.02                          65.71
# 48                                 68.51                          66.06
# 49                                 68.74                          66.27
# 50                                 67.90                          66.27
# 51                                 69.91                          66.41
# 52                                 70.32                          66.62
# 53                                 68.71                          66.70
# 54                                 71.33                          66.70
# 55                                 68.89                          66.76
# 56                                 69.29                          66.78
# 57                                 69.95                          66.99
# 58                                 70.20                          67.00
# 59                                 68.92                          67.01

# %%
import numpy as np

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/TaniaGuevara12/Estad-stica-/refs/heads/main/life_expectancy.csv')
df.head(60)
X = df['Sum of Females  Life Expectancy']
Y = df['Sum of Life Expectancy  (both sexes)']

df.dropna(inplace=True)

# 1. Establesca una variable dependiente ( Y ) y una variable independiente ( X ).

# Variable independiente: Sum of Males Life Expectancy
# Variable dependiente: Sum of Females Life Expectancy

# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt
plt.scatter(X, Y)
plt.xlabel('Sum of Males Life Expectancy')
plt.ylabel('Sum of Females Life Expectancy')
plt.title('Diagrama de dispersión')
plt.show()

# 3. ¿Los datos soportan la suposición de linealidad?
# si se puede trazar una linea

# 4. Calcule el coeficiente de correlación e interprete el resultado.
Sxx = np.sum(   (X - np.mean(X)) ** 2    )
Sxy = np.sum(    (Y - np.mean(Y))  * (X - np.mean(X))             )
Syy = np.sum(   (Y - np.mean(Y)   )   **   2)
r = Sxy / np.sqrt(Sxx * Syy)
print('Coeficiente de correlación:', r)

# 5. Calcule el coeficiente de determinación e interprete el resultado.
r2 = r ** 2
print('Coeficiente de determinación:', r2)

# 6. Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de dispersión.
b1 = Sxy / Sxx
b0 = np.mean(Y) - b1 * np.mean(X)

fun = lambda x: b1 * x + b0  # crea una función para la regresión lineal ajustada

Yc = fun(X)

plt.plot(X, Yc, color = 'purple', linestyle = '--')


# Graficar la recta de regresión

# 7. Obtenga un intervalo de confianza del 95% para la pendiente de la recta de regresión ajustada ( b1 )
nivel_de_significancia = 0.05
from scipy.stats import t
T = t.ppf(1 - nivel_de_significancia / 2, df = X.size - 2)
se_b1 = np.sqrt(np.sum((Y - Yc) ** 2) / (Y.size - 2)) / np.sqrt(Sxx)
confianza_b1 = b1 - T * se_b1, b1 + T * se_b1
print(f'intervalo de confianza de {1 - nivel_de_significancia: 0.0%}')
print(f'{confianza_b1[0] : 0.4f} < b1 < {confianza_b1[1] : 0.4f} \n')

# 8. Calcule los residuales y trace un nuevo gráfico de dispersión. Comente, ¿Parece que se verifican los supuestos?
residuales = Y - Yc
plt.scatter(X, residuales)
plt.xlabel('Sum of Males Life Expectancy')
plt.ylabel('Residuales')
plt.title('Residuales')
ax = plt.gca()
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.axhline(y = 0, color = 'gray', linestyle = '--')

# 9. Realice la prueba de Shapiro para los residuales y comente el resultado.
from scipy.stats import shapiro
_, valor_p_sh = shapiro(residuales)
print(f'valor-p para shapiro: {valor_p_sh: 0.4f}\n')

# 11. Tres estudiantes sacaron 70, 75 y 84 de calificación. Según la recta de
# regresión ajustada, ¿cuáles son los resultados esperados para estos tres alumnos?

print(f'Para x = 70, y = {fun(70): 0.0f}')
print(f'Para x = 75, y = {fun(75): 0.0f}')
print(f'Para x = 84, y = {fun(84): 0.0f}\n')

# 12. Realice una tabla ANOVA e interprete el resultado.

print (f"Sxx: {Sxx}")
print (f"Sxy: {Sxy}")
print (f"Syy: {Syy}")
print (f"SSE: {np.sum(residuales ** 2)}")
print (f"SSR: {np.sum(residuales ** 2)}")
print (f"SST: {np.sum((Y - np.mean(Y)) ** 2)}")
print (f"MSR: {np.sum(residuales ** 2) / (Y.size - 2)}")
print (f"MSE: {np.sum(residuales ** 2) / (Y.size - 2)}")
print (f"F: {np.sum(residuales ** 2) / (Y.size - 2) / np.sum((Y - np.mean(Y)) ** 2) / (Y.size - 1)}")
# Out:
# Coeficiente de correlación: 0.9945658481132965
# Coeficiente de determinación: 0.9891612262333208
# intervalo de confianza de  95%
#  0.9523 < b1 <  0.9807
#
# valor-p para shapiro:  0.0016
#
# Para x = 70, y =  68
# Para x = 75, y =  72
# Para x = 84, y =  81
#
# Sxx: 15481.853878
# Sxy: 14963.017393999999
# Syy: 14620.031662000001
# SSE: 158.46321564610062
# SSR: 158.46321564610062
# SST: 14620.031662000001
# MSR: 0.8003192709399022
# MSE: 0.8003192709399022
# F: 2.7508181733614807e-07

# %%
df.columns
# Out:
# Index(['Country', 'Sum of Females  Life Expectancy',
#        'Sum of Life Expectancy  (both sexes)',
#        'Sum of Males  Life Expectancy'],
#       dtype='object')
