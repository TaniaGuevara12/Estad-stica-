# %%
import pandas as pd
import numpy as np
df = pd.read_csv('https://raw.githubusercontent.com/TaniaGuevara12/Estad-stica-/refs/heads/main/smart_logistics_dataset%20(3).csv')

df.dropna(inplace=True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 16 columns]

# %%
df.drop(columns = ['Timestamp'], inplace = True)
df
# Out:
#      Inventory_Level  Humidity Traffic_Status  Waiting_Time  \
# 1                491      54.3          Heavy            16
# 3                330      52.3          Heavy            37
# 7                222      64.2         Detour            30
# 9                389      57.3          Clear            52
# 11               234      63.6         Detour            13
# ..               ...       ...            ...           ...
# 993              420      62.8          Clear            31
# 994              143      64.1         Detour            32
# 995              264      70.0          Heavy            32
# 996              479      77.9         Detour            56
# 999              157      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 10 columns]

# %%
df["Asset_ID"].unique()
# Out:
# array(['Truck_6', 'Truck_9', 'Truck_2', 'Truck_10', 'Truck_8', 'Truck_3',
#        'Truck_5', 'Truck_4', 'Truck_1', 'Truck_7'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Asset_ID)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# Estos datos no aportan nada.
# Out:
#                 df         sum_sq     mean_sq         F    PR(>F)
# C(Asset_ID)    9.0    1185.003921  131.667102  0.635796  0.766885
# Residual     727.0  150554.551031  207.090166       NaN       NaN

# %%
df.drop(columns = ["Asset_ID"], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234
# ..                   ...       ...        ...              ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   89.8701    73.6867              264
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 15 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Latitude'], kde = True, color = 'turquoise')
plt.title('Histograma de Latitude')
plt.xlabel('Latitude')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.

# %%
df.drop(columns = ['Latitude'], inplace = True)
df
# Out:
#                Timestamp  Longitude  Inventory_Level Shipment_Status  \
# 1    2024-10-30 07:53:51  -131.7086              491      In Transit
# 3    2024-10-28 00:50:54    -1.4788              330       Delivered
# 7    2024-09-28 09:08:23  -126.5348              222      In Transit
# 9    2024-11-09 00:48:26  -135.2676              389      In Transit
# 11   2024-02-02 22:28:16   156.1262              234       Delivered
# ..                   ...        ...              ...             ...
# 993  2024-10-14 10:21:17   -36.5198              420         Delayed
# 994  2024-06-13 00:29:04   175.0702              143       Delivered
# 995  2024-07-22 16:30:00    73.6867              264       Delivered
# 996  2024-04-30 04:58:58  -177.1239              479       Delivered
# 999  2024-09-18 19:39:24  -114.4198              157         Delayed
#
#      Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1           22.5      54.3          Heavy            16
# 3           25.4      52.3          Heavy            37
# 7           23.3      64.2         Detour            30
# 9           21.9      57.3          Clear            52
# 11          29.7      63.6         Detour            13
# ..           ...       ...            ...           ...
# 993         21.6      62.8          Clear            31
# 994         21.6      64.1         Detour            32
# 995         26.9      70.0          Heavy            32
# 996         23.7      77.9         Detour            56
# 999         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Longitude'], kde = True, color = 'turquoise')
plt.title('Histograma de Longitude')
plt.xlabel('Longitude')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.

# %%
df.drop(columns = ['Longitude'], inplace = True)
df
# Out:
#                Timestamp  Inventory_Level Shipment_Status  Temperature  \
# 1    2024-10-30 07:53:51              491      In Transit         22.5
# 3    2024-10-28 00:50:54              330       Delivered         25.4
# 7    2024-09-28 09:08:23              222      In Transit         23.3
# 9    2024-11-09 00:48:26              389      In Transit         21.9
# 11   2024-02-02 22:28:16              234       Delivered         29.7
# ..                   ...              ...             ...          ...
# 993  2024-10-14 10:21:17              420         Delayed         21.6
# 994  2024-06-13 00:29:04              143       Delivered         21.6
# 995  2024-07-22 16:30:00              264       Delivered         26.9
# 996  2024-04-30 04:58:58              479       Delivered         23.7
# 999  2024-09-18 19:39:24              157         Delayed         18.7
#
#      Humidity Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1        54.3          Heavy            16                      439
# 3        52.3          Heavy            37                      227
# 7        64.2         Detour            30                      459
# 9        57.3          Clear            52                      127
# 11       63.6         Detour            13                      406
# ..        ...            ...           ...                      ...
# 993      62.8          Clear            31                      242
# 994      64.1         Detour            32                      307
# 995      70.0          Heavy            32                      188
# 996      77.9         Detour            56                      276
# 999      73.6          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 13 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Inventory_Level'], kde = True, color = 'turquoise')
plt.title('Histograma de Inventory_Level')
plt.xlabel('Inventory_Level')
plt.ylabel('Frecuencia')
plt.title('Distribucion de Inventory_Level')
# Out:
# Text(0.5, 1.0, 'Distribucion de Inventory_Level')

# %%
df['Shipment_Status'].unique()
# Out:
# array(['In Transit', 'Delivered', 'Delayed'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
modelo = smf.ols('Waiting_Time ~ C(Shipment_Status)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #anova de un sola via
tabla_anova
# No se rechaza la H0.
# Out:
#                        df         sum_sq     mean_sq         F    PR(>F)
# C(Shipment_Status)    2.0     208.098709  104.049355  0.504002  0.604317
# Residual            734.0  151531.456243  206.446126       NaN       NaN

# %%
df.drop(columns = ['Shipment_Status'], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  Temperature  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491         22.5
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330         25.4
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222         23.3
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389         21.9
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234         29.7
# ..                   ...       ...        ...              ...          ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420         21.6
# 994  2024-06-13 00:29:04   44.2477   175.0702              143         21.6
# 995  2024-07-22 16:30:00   89.8701    73.6867              264         26.9
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479         23.7
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157         18.7
#
#      Humidity Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1        54.3          Heavy            16                      439
# 3        52.3          Heavy            37                      227
# 7        64.2         Detour            30                      459
# 9        57.3          Clear            52                      127
# 11       63.6         Detour            13                      406
# ..        ...            ...           ...                      ...
# 993      62.8          Clear            31                      242
# 994      64.1         Detour            32                      307
# 995      70.0          Heavy            32                      188
# 996      77.9         Detour            56                      276
# 999      73.6          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 14 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Temperature)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# Se rechaza la hipotesis nula.
# Out:
#                    df         sum_sq     mean_sq         F    PR(>F)
# C(Temperature)  119.0   21204.060583  178.185383  0.842226  0.876205
# Residual        617.0  130535.494370  211.564821       NaN       NaN

# %%
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  Temperature  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491         22.5
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330         25.4
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222         23.3
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389         21.9
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234         29.7
# ..                   ...       ...        ...              ...          ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420         21.6
# 994  2024-06-13 00:29:04   44.2477   175.0702              143         21.6
# 995  2024-07-22 16:30:00   89.8701    73.6867              264         26.9
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479         23.7
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157         18.7
#
#      Humidity Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1        54.3          Heavy            16                      439
# 3        52.3          Heavy            37                      227
# 7        64.2         Detour            30                      459
# 9        57.3          Clear            52                      127
# 11       63.6         Detour            13                      406
# ..        ...            ...           ...                      ...
# 993      62.8          Clear            31                      242
# 994      64.1         Detour            32                      307
# 995      70.0          Heavy            32                      188
# 996      77.9         Detour            56                      276
# 999      73.6          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 14 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Temperature'], kde = True, color = 'turquoise')
plt.title('Histograma de Temperature')
plt.xlabel('Temperature')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.

# %%
df.drop(columns = ['Temperature'], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  Humidity  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491      54.3
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330      52.3
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222      64.2
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389      57.3
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234      63.6
# ..                   ...       ...        ...              ...       ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420      62.8
# 994  2024-06-13 00:29:04   44.2477   175.0702              143      64.1
# 995  2024-07-22 16:30:00   89.8701    73.6867              264      70.0
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479      77.9
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157      73.6
#
#     Traffic_Status  Waiting_Time  User_Transaction_Amount  \
# 1            Heavy            16                      439
# 3            Heavy            37                      227
# 7           Detour            30                      459
# 9            Clear            52                      127
# 11          Detour            13                      406
# ..             ...           ...                      ...
# 993          Clear            31                      242
# 994         Detour            32                      307
# 995          Heavy            32                      188
# 996         Detour            56                      276
# 999          Clear            55                      323
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 13 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Humidity)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# Se rechaza la hipotesis nula.
# Out:
#                 df        sum_sq     mean_sq        F    PR(>F)
# C(Humidity)  273.0  54928.590667  201.203629  0.96226  0.635462
# Residual     463.0  96810.964286  209.094955      NaN       NaN

# %%
df.drop(columns = ['Humidity'], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level Traffic_Status  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491          Heavy
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330          Heavy
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222         Detour
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389          Clear
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234         Detour
# ..                   ...       ...        ...              ...            ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420          Clear
# 994  2024-06-13 00:29:04   44.2477   175.0702              143         Detour
# 995  2024-07-22 16:30:00   89.8701    73.6867              264          Heavy
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479         Detour
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157          Clear
#
#      Waiting_Time  User_Transaction_Amount  User_Purchase_Frequency  \
# 1              16                      439                        7
# 3              37                      227                        5
# 7              30                      459                        9
# 9              52                      127                        7
# 11             13                      406                       10
# ..            ...                      ...                      ...
# 993            31                      242                       10
# 994            32                      307                       10
# 995            32                      188                        1
# 996            56                      276                        7
# 999            55                      323                        9
#
#     Logistics_Delay_Reason  Asset_Utilization  Demand_Forecast  \
# 1                  Weather               80.9              174
# 3                  Traffic               97.4              160
# 7                  Traffic               73.8              253
# 9       Mechanical Failure               63.1              224
# 11                 Traffic               85.5              238
# ..                     ...                ...              ...
# 993                Weather               95.6              221
# 994                Traffic               64.0              168
# 995                Weather               79.2              213
# 996                Weather               83.7              272
# 999     Mechanical Failure               81.3              141
#
#      Logistics_Delay
# 1                  1
# 3                  1
# 7                  0
# 9                  0
# 11                 0
# ..               ...
# 993                1
# 994                0
# 995                1
# 996                0
# 999                1
#
# [737 rows x 12 columns]

# %%
df['Traffic_Status'].unique()
# Out:
# array(['Heavy', 'Detour', 'Clear'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
modelo = smf.ols('Waiting_Time ~ C(Traffic_Status)', data = df).fit()
tabla_anova = sm.stats.anova_lm(modelo) #anova de un sola via
tabla_anova
# Out:
#                       df         sum_sq     mean_sq         F    PR(>F)
# C(Traffic_Status)    2.0     168.452231   84.226116  0.407874  0.665213
# Residual           734.0  151571.102721  206.500140       NaN       NaN

# %%
df.drop(columns = ["Traffic_Status"], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  Waiting_Time  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491            16
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330            37
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222            30
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389            52
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234            13
# ..                   ...       ...        ...              ...           ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420            31
# 994  2024-06-13 00:29:04   44.2477   175.0702              143            32
# 995  2024-07-22 16:30:00   89.8701    73.6867              264            32
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479            56
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 11 columns]

# %%
df["Waiting_Time"].unique()
# Out:
# array([16, 37, 30, 52, 13, 38, 54, 45, 58, 21, 31, 20, 57, 35, 22, 14, 26,
#        41, 39, 50, 19, 12, 40, 15, 17, 46, 55, 23, 49, 32, 34, 24, 51, 59,
#        56, 25, 53, 29, 18, 43, 44, 42, 60, 36, 10, 48, 27, 33, 28, 47, 11])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Waiting_Time'], kde = True, color = 'turquoise')
plt.xlabel('Tiempo de Espera')
plt.ylabel('Fecuencia')
plt.title('Distriucion de Tiempo de Espera')

plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# %%
df.drop(columns = ['Waiting_Time'], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234
# ..                   ...       ...        ...              ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   89.8701    73.6867              264
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast  Logistics_Delay
# 1                 80.9              174                1
# 3                 97.4              160                1
# 7                 73.8              253                0
# 9                 63.1              224                0
# 11                85.5              238                0
# ..                 ...              ...              ...
# 993               95.6              221                1
# 994               64.0              168                0
# 995               79.2              213                1
# 996               83.7              272                0
# 999               81.3              141                1
#
# [737 rows x 10 columns]

# %%
df["User_Transaction_Amount"].unique()
# Out:
# array([439, 227, 459, 127, 406, 215, 320, 487, 298, 315, 174, 152, 396,
#        354, 121, 220, 184, 392, 209, 235, 292, 475, 311, 201, 310, 379,
#        274, 308, 232, 282, 258, 425, 424, 467, 139, 456, 205, 173, 154,
#        191, 100, 193, 418, 378, 370, 496, 415, 167, 485, 344, 219, 486,
#        214, 267, 451, 268, 244, 432, 366, 330, 410, 468, 225, 120, 377,
#        335, 302, 416, 340, 145, 243, 180, 111, 187, 156, 421, 325, 189,
#        138, 345, 246, 247, 204, 461, 499, 155, 261, 390, 464, 482, 312,
#        447, 341, 106, 101, 226, 140, 413, 323, 238, 233, 181, 319, 490,
#        321, 318, 257, 229, 497, 287, 266, 466, 358, 494, 305, 168, 210,
#        481, 423, 231, 360, 419, 107, 195, 112, 309, 477, 146, 463, 103,
#        170, 393, 367, 141, 104, 213, 242, 473, 389, 124, 332, 384, 448,
#        317, 126, 216, 251, 363, 342, 108, 336, 495, 188, 236, 147, 295,
#        197, 417, 125, 348, 347, 472, 498, 476, 414, 196, 259, 454, 202,
#        437, 115, 409, 453, 134, 402, 484, 314, 151, 211, 349, 372, 445,
#        303, 368, 465, 163, 460, 491, 185, 291, 280, 329, 400, 362, 338,
#        129, 137, 478, 271, 398, 442, 286, 373, 300, 182, 118, 408, 237,
#        388, 149, 382, 375, 452, 171, 444, 440, 474, 455, 166, 256, 203,
#        479, 339, 343, 113, 144, 135, 443, 142, 364, 192, 260, 262, 359,
#        153, 429, 293, 283, 160, 177, 264, 365, 114, 430, 381, 157, 333,
#        458, 199, 284, 399, 109, 297, 161, 350, 175, 207, 277, 301, 322,
#        357, 158, 492, 159, 230, 431, 179, 183, 369, 353, 405, 276, 228,
#        306, 272, 385, 123, 281, 190, 395, 253, 102, 241, 316, 446, 165,
#        404, 327, 457, 223, 480, 234, 279, 462, 307, 263, 289, 172, 386,
#        122, 162, 240, 290, 352, 143, 222, 131, 387, 427, 450, 361, 136,
#        380, 401, 194, 469, 128, 265, 176, 483, 198, 255, 130, 324, 254,
#        407, 334, 488, 428, 500, 245, 105, 148, 449])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['User_Transaction_Amount'], kde = True, color = 'turquoise')
plt.title('Histograma de User_Transaction_Amount')
plt.xlabel('User_Transaction_Amount')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.

# %%
df.drop(columns = ['User_Transaction_Amount'], inplace = True)
df
# Out:
#                Timestamp  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  -25.2768   156.1262              234
# ..                   ...       ...        ...              ...
# 993  2024-10-14 10:21:17   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   89.8701    73.6867              264
# 996  2024-04-30 04:58:58  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   59.8356  -114.4198              157
#
#      User_Purchase_Frequency Logistics_Delay_Reason  Asset_Utilization  \
# 1                          7                Weather               80.9
# 3                          5                Traffic               97.4
# 7                          9                Traffic               73.8
# 9                          7     Mechanical Failure               63.1
# 11                        10                Traffic               85.5
# ..                       ...                    ...                ...
# 993                       10                Weather               95.6
# 994                       10                Traffic               64.0
# 995                        1                Weather               79.2
# 996                        7                Weather               83.7
# 999                        9     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 9 columns]

# %%
df["User_Purchase_Frequency"].unique()
# Out:
# array([ 7,  5,  9, 10,  3,  4,  1,  2,  6,  8])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(User_Purchase_Frequency)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

#no se rechaza la hipotesis nula
# Out:
#                                df         sum_sq     mean_sq         F  \
# C(User_Purchase_Frequency)    9.0    3144.428059  349.380895  1.709342
# Residual                    727.0  148595.126893  204.394948       NaN
#
#                               PR(>F)
# C(User_Purchase_Frequency)  0.083103
# Residual                         NaN

# %%
df.drop(columns = ['User_Purchase_Frequency'], inplace = True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount Logistics_Delay_Reason  Asset_Utilization  \
# 1                        439                Weather               80.9
# 3                        227                Traffic               97.4
# 7                        459                Traffic               73.8
# 9                        127     Mechanical Failure               63.1
# 11                       406                Traffic               85.5
# ..                       ...                    ...                ...
# 993                      242                Weather               95.6
# 994                      307                Traffic               64.0
# 995                      188                Weather               79.2
# 996                      276                Weather               83.7
# 999                      323     Mechanical Failure               81.3
#
#      Demand_Forecast  Logistics_Delay
# 1                174                1
# 3                160                1
# 7                253                0
# 9                224                0
# 11               238                0
# ..               ...              ...
# 993              221                1
# 994              168                0
# 995              213                1
# 996              272                0
# 999              141                1
#
# [737 rows x 15 columns]

# %%
df['Logistics_Delay_Reason'].unique()
# Out:
# array(['Weather', 'Traffic', 'Mechanical Failure'], dtype=object)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Logistics_Delay_Reason)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# No se rechaza la hipotesis nula.
# Out:
#                               df         sum_sq     mean_sq         F  \
# C(Logistics_Delay_Reason)    2.0     430.598291  215.299145  1.044417
# Residual                   734.0  151308.956662  206.142993       NaN
#
#                              PR(>F)
# C(Logistics_Delay_Reason)  0.352419
# Residual                        NaN

# %%
df.drop(columns = ['Logistics_Delay_Reason'], inplace = True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  Asset_Utilization  Demand_Forecast  \
# 1                        439               80.9              174
# 3                        227               97.4              160
# 7                        459               73.8              253
# 9                        127               63.1              224
# 11                       406               85.5              238
# ..                       ...                ...              ...
# 993                      242               95.6              221
# 994                      307               64.0              168
# 995                      188               79.2              213
# 996                      276               83.7              272
# 999                      323               81.3              141
#
#      Logistics_Delay
# 1                  1
# 3                  1
# 7                  0
# 9                  0
# 11                 0
# ..               ...
# 993                1
# 994                0
# 995                1
# 996                0
# 999                1
#
# [737 rows x 14 columns]

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Asset_Utilization)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# No se rechaza la H0.
# Out:
#                          df        sum_sq     mean_sq         F   PR(>F)
# C(Asset_Utilization)  336.0  71460.588286  212.680322  1.059706  0.28869
# Residual              400.0  80278.966667  200.697417       NaN      NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Asset_Utilization'], kde = True, color = 'turquoise')
plt.title('Histograma de Asset_Utilization')
plt.xlabel('Asset_Utilization	')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.drop(columns = ['Asset_Utilization'], inplace = True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  Demand_Forecast  Logistics_Delay
# 1                        439              174                1
# 3                        227              160                1
# 7                        459              253                0
# 9                        127              224                0
# 11                       406              238                0
# ..                       ...              ...              ...
# 993                      242              221                1
# 994                      307              168                0
# 995                      188              213                1
# 996                      276              272                0
# 999                      323              141                1
#
# [737 rows x 13 columns]

# %%
df["Demand_Forecast"].unique()
# Out:
# array([174, 160, 253, 224, 238, 114, 231, 256, 170, 248, 195, 235, 135,
#        282, 262, 101, 155, 240, 242, 205, 222, 266, 255, 129, 183, 209,
#        113, 265, 154, 289, 143, 128, 127, 290, 169, 241, 236, 260, 182,
#        212, 254, 264, 225, 204, 172, 245, 252, 211, 156, 151, 105, 125,
#        214, 217, 165, 136, 233, 137, 150, 140, 298, 141, 263, 223, 285,
#        273, 296, 100, 106, 284, 226, 149, 181, 109, 177, 184, 220, 111,
#        281, 126, 110, 107, 294, 189, 152, 145, 270, 118, 230, 117, 115,
#        191, 208, 166, 131, 277, 186, 272, 175, 158, 162, 138, 246, 179,
#        201, 102, 257, 116, 130, 237, 112, 206, 286, 139, 147, 229, 249,
#        269, 213, 271, 124, 279, 185, 292, 188, 200, 268, 221, 198, 261,
#        104, 219, 259, 247, 146, 288, 133, 176, 228, 134, 234, 196, 197,
#        123, 187, 251, 280, 132, 171, 192, 244, 300, 203, 122, 215, 297,
#        199, 164, 103, 159, 163, 207, 168, 274, 173, 202, 291, 108, 180,
#        142, 239, 299, 287, 283, 276, 157, 243, 119, 120, 190, 210, 267,
#        144, 194, 293, 161, 275, 153, 167, 218, 278, 193, 232, 295, 216,
#        148, 178, 227, 250, 258])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Demand_Forecast)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# No se rechaza la H0.
# Out:
#                        df         sum_sq     mean_sq         F   PR(>F)
# C(Demand_Forecast)  199.0   45875.589476  230.530600  1.169377  0.08601
# Residual            537.0  105863.965476  197.139601       NaN      NaN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Demand_Forecast'], kde = True, color = 'turquoise')
plt.title('Histograma de Demand_Forecast')
plt.xlabel('Demand_Forecast')
plt.ylabel('Frecuencia')
plt.title('Distribucion de frecuencia')

plt.gca().spines[['right']].set_visible(False)
plt.gca().spines[['top']].set_visible(False)

# No hay datos atipicos.

# %%
df["Logistics_Delay"].unique()
# Out:
# array([1, 0])

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

modelo=smf.ols("Waiting_Time ~ C(Logistics_Delay)",data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo)
tabla_anova

# No se rechaza la H0.
# Out:
#                        df         sum_sq     mean_sq         F    PR(>F)
# C(Logistics_Delay)    1.0     532.543800  532.543800  2.588635  0.108062
# Residual            735.0  151207.011153  205.723825       NaN       NaN

# %%
df.drop(columns = ["Logistics_Delay"], inplace = True)
df
# Out:
#                Timestamp  Asset_ID  Latitude  Longitude  Inventory_Level  \
# 1    2024-10-30 07:53:51   Truck_6   22.2748  -131.7086              491
# 3    2024-10-28 00:50:54   Truck_9   42.3900    -1.4788              330
# 7    2024-09-28 09:08:23   Truck_9   46.5643  -126.5348              222
# 9    2024-11-09 00:48:26   Truck_2   54.1683  -135.2676              389
# 11   2024-02-02 22:28:16  Truck_10  -25.2768   156.1262              234
# ..                   ...       ...       ...        ...              ...
# 993  2024-10-14 10:21:17   Truck_4   46.9729   -36.5198              420
# 994  2024-06-13 00:29:04   Truck_1   44.2477   175.0702              143
# 995  2024-07-22 16:30:00   Truck_6   89.8701    73.6867              264
# 996  2024-04-30 04:58:58   Truck_5  -10.4792  -177.1239              479
# 999  2024-09-18 19:39:24   Truck_8   59.8356  -114.4198              157
#
#     Shipment_Status  Temperature  Humidity Traffic_Status  Waiting_Time  \
# 1        In Transit         22.5      54.3          Heavy            16
# 3         Delivered         25.4      52.3          Heavy            37
# 7        In Transit         23.3      64.2         Detour            30
# 9        In Transit         21.9      57.3          Clear            52
# 11        Delivered         29.7      63.6         Detour            13
# ..              ...          ...       ...            ...           ...
# 993         Delayed         21.6      62.8          Clear            31
# 994       Delivered         21.6      64.1         Detour            32
# 995       Delivered         26.9      70.0          Heavy            32
# 996       Delivered         23.7      77.9         Detour            56
# 999         Delayed         18.7      73.6          Clear            55
#
#      User_Transaction_Amount  User_Purchase_Frequency Logistics_Delay_Reason  \
# 1                        439                        7                Weather
# 3                        227                        5                Traffic
# 7                        459                        9                Traffic
# 9                        127                        7     Mechanical Failure
# 11                       406                       10                Traffic
# ..                       ...                      ...                    ...
# 993                      242                       10                Weather
# 994                      307                       10                Traffic
# 995                      188                        1                Weather
# 996                      276                        7                Weather
# 999                      323                        9     Mechanical Failure
#
#      Asset_Utilization  Demand_Forecast
# 1                 80.9              174
# 3                 97.4              160
# 7                 73.8              253
# 9                 63.1              224
# 11                85.5              238
# ..                 ...              ...
# 993               95.6              221
# 994               64.0              168
# 995               79.2              213
# 996               83.7              272
# 999               81.3              141
#
# [737 rows x 15 columns]

# %%
# mapa de calor
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.select_dtypes(include=np.number).corr()
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", square=True, cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
# Out:
# Text(0.5, 1.0, 'Mapa de Calor de la Matriz de Correlación')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import statsmodels.api as sm
import matplotlib.pyplot as plt

X = df[['Latitude',	'Longitude',	'Inventory_Level',	'Temperature']]
Y = df["Waiting_Time"]

# Datos de entrenamiento y datos de prueba

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

X_train_constante = sm.add_constant(X_train)
X_test_constante = sm.add_constant(X_test)

modelo = sm.OLS(Y_train, X_train_constante).fit()


Yc = modelo.predict(X_test_constante)

plt.scatter(Y_test, Yc)

r2 = r2_score(Y_test, Yc)
print(f'Coeficiente de correlacion: {r2: 0.4f}\n')
# Out:
# Coeficiente de correlacion: -0.0109

# %%
b0, b1, b2, b3, b4 = modelo.params

Fun = lambda x1, x2, x3, x4: b0 + b1 * x1 + b2 * x2 + b3 * x3 + b4 * x4

# si se trata de un modelo de predicción de demanda, un modelo de tiempo de espera
Fun(432, 60, 2, 120000)
# Out:
# 13035.647927918895

# %%
from statsmodels.formula.api import ols

moedo_2 = ols(formula = "Waiting_Time ~ Latitude + Longitude + Inventory_Level + Temperature", data = df).fit()
tabla_anova = sm.stats.anova_lm(moedo_2, typ = 2)
tabla_anova
# Out:
#                         sum_sq     df         F    PR(>F)
# Latitude              2.349989    1.0  0.011346  0.915202
# Longitude             0.000397    1.0  0.000002  0.998896
# Inventory_Level       2.526366    1.0  0.012197  0.912090
# Temperature         115.063561    1.0  0.555520  0.456310
# Residual         151617.470315  732.0       NaN       NaN

# %% [markdown]
# ***CONCLUSIÓN***
#
# El valor P, también conocido como PR(>F), representa la probabilidad de obtener los resultados observados bajo la suposición de que la hipótesis nula es verdadera. En otras palabras, este valor indica la probabilidad de que los resultados obtenidos sean simplemente el resultado del azar, y no de una relación real entre la variable independiente y la variable dependiente. En este contexto, la hipótesis nula sugiere que la variable independiente no tiene ningún efecto sobre la variable dependiente.
#
# Cuando el valor P es inferior a 0.05, se considera que hay un efecto significativo, lo que significa que la probabilidad de que los resultados sean el resultado del azar es menor al 5%. Sin embargo, en este caso, los valores P de todas las variables independientes (latitud, longitud, nivel de inventario y temperatura) son considerablemente mayores a 0.05. Esto indica que ninguna de estas variables influye de manera significativa en el tiempo de espera.
